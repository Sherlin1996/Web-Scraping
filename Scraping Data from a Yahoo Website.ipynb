# %%
import requests
from bs4 import BeautifulSoup 
import pandas as pd

# %%
url = requests.get('https://tw.stock.yahoo.com/tw-etf/volume')
soup = BeautifulSoup(url.text, "html.parser")    # 轉換內容
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
Urls=[]
for url in soup.find_all('a',class_='Pos(a) W(100%) H(100%) T(0) Start(0) Z(0)'):  #每個股票的URL
    Urls.append(url.get('href'))
Urls
# Out:
# ['https://tw.stock.yahoo.com/quote/00632R.TW',
#  'https://tw.stock.yahoo.com/quote/00929.TW',
#  'https://tw.stock.yahoo.com/quote/00712.TW',
#  'https://tw.stock.yahoo.com/quote/00665L.TW',
#  'https://tw.stock.yahoo.com/quote/00637L.TW',
#  'https://tw.stock.yahoo.com/quote/00878.TW',
#  'https://tw.stock.yahoo.com/quote/00687B.TWO',
#  'https://tw.stock.yahoo.com/quote/00919.TW',
#  'https://tw.stock.yahoo.com/quote/00680L.TW',
#  'https://tw.stock.yahoo.com/quote/0056.TW',
#  'https://tw.stock.yahoo.com/quote/00720B.TWO',
#  'https://tw.stock.yahoo.com/quote/00679B.TWO',
#  'https://tw.stock.yahoo.com/quote/00931B.TWO',
#  'https://tw.stock.yahoo.com/quote/00715L.TW',
#  'https://tw.stock.yahoo.com/quote/00753L.TW',
#  'https://tw.stock.yahoo.com/quote/00673R.TW',
#  'https://tw.stock.yahoo.com/quote/00650L.TW',
#  'https://tw.stock.yahoo.com/quote/00751B.TWO',
#  'https://tw.stock.yahoo.com/quote/00933B.TWO',
#  'https://tw.stock.yahoo.com/quote/00688L.TW',
# ...

# %%
dict = {}
Name = []
Number = []
Price = []

# %%
for url in Urls:
    soup = BeautifulSoup(requests.get(url).text,'html.parser')
    for name in soup.find_all('h1',class_='C($c-link-text) Fw(b) Fz(24px) Mend(8px)'):       #股名
        Name.append(name.text)  
        if soup.find_all('span',class_='Fz(32px) Fw(b) Lh(1) Mend(16px) D(f) Ai(c) C($c-trend-down)'):  #依股價狀態有不同標籤            for p in soup.find_all('span',class_='Fz(32px) Fw(b) Lh(1) Mend(16px) D(f) Ai(c) C($c-trend-down)'):
                Price.append(p.text)                                                                     # 表示狀態為下跌
        elif soup.find_all('span',class_='Fz(32px) Fw(b) Lh(1) Mend(16px) D(f) Ai(c) C($c-trend-up)'):   # 表示狀態為上漲
            for p in soup.find_all('span',class_='Fz(32px) Fw(b) Lh(1) Mend(16px) D(f) Ai(c) C($c-trend-up)'):
                Price.append(p.text)
        elif soup.find_all('span',class_='Fz(32px) Fw(b) Lh(1) Mend(16px) D(f) Ai(c)'):                  #表示狀態為平盤
            for p in soup.find_all('span',class_='Fz(32px) Fw(b) Lh(1) Mend(16px) D(f) Ai(c)'):
                Price.append(p.text)
        else:
            Price.append("--")
        for num in soup.find_all('span',class_='C($c-icon) Fz(24px) Mend(20px)'):            #股號
            Number.append(num.text)

# %%
dict['Name']=Name
dict['Number']=Number
dict['Price']=Price

# %%
pd.set_option('display.max_rows', None)
df = pd.DataFrame(dict)
df.to_csv('YahooTOP100ETF.csv', index=False, encoding='utf-8')  #轉出csv
df
# Out:
#            Name  Number   Price
# 0      元大台灣50反1  00632R    4.91
# 1      復華台灣科技優息   00929   17.22
# 2       復華富時不動產   00712    8.72
# 3      富邦恒生國企正2  00665L    6.13
# 4     元大滬深300正2  00637L   12.46
# 5       國泰永續高股息   00878   19.86
# 6       國泰20年美債  00687B   28.36
# 7      群益台灣精選高息   00919   20.32
# 8      元大美債20正2  00680L    7.48
# 9         元大高股息    0056   33.47
# 10     元大投資級公司債  00720B   31.34
# 11      元大美債20年  00679B   27.75
# 12      統一美債20年  00931B   13.43
# 13     期街口布蘭特正2  00715L   18.18
# 14     中信中國50正2  00753L    7.41
# 15   期元大S&P原油反1  00673R    7.34
# 16       復華香港正2  00650L    9.73
# 17   元大AAA至A公司債  00751B   31.20
# 18    國泰10Y+金融債  00933B   14.72
# 19    國泰20年美債正2  00688L    7.42
# 20   富邦NASDAQ反1  00671R    4.98
# 21    富邦特選高股息30   00900   12.54
# 22      富邦美債20年  00696B   28.75
# 23      中信關鍵半導體   00891   14.27
# 24     國泰台灣領袖50   00922   15.33
# 25      國泰台灣5G+   00881   16.67
# 26      中信中國高股息   00882   10.51
# 27       富邦上証正2  00633L   31.20
# ...
